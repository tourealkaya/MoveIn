# %%
import socket
import numpy as np
import json

def Getdata(path):
    with open(path) as f:
        salles = {}
        noeuds = {}
        chemins = []
        # relations = []
        while True:
            line = f.readline()
            if (not line) or (line.strip() == '------------------'):
                break
            line = line.strip()
            data = line.split(",")
            salles[data[0]] = [data[1], data[2]]
        while True:
            line = f.readline()
            if (not line) or (line.strip() == '------------------'):
                break
            line = line.strip()
            data = line.split(",")
            noeuds[data[0]] = [data[1], data[2]]
        while True:
            line = f.readline()

            if (not line) or (line.strip() == '------------------'):
                break
            line = line.strip()
            data = line.split(",")

            chemins.append([data[0], data[1], data[2]])
    return {"salles": salles, "noeuds": noeuds, "chemins": chemins}








import heapq


def dijkstra(graph, start, end):
    # Initialisation
    print("start,end",start,end)
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    queue = [(0, start, [])]

    while queue:
        # On récupère le noeud avec la plus petite distance
        (cost, node, path) = heapq.heappop(queue)

        # Si on atteint le noeud d'arrivée, on renvoie le chemin
        if node == end:
            return path + [node]

        # Sinon, on continue à explorer les voisins
        for neighbor, weight in graph[node].items():
            new_cost = cost + weight
            if new_cost < distances[neighbor]:
                distances[neighbor] = new_cost
                new_path = path + [node]
                heapq.heappush(queue, (new_cost, neighbor, new_path))

    # Si on ne peut pas atteindre le noeud d'arrivée, on renvoie None
    return None

def deriv(tab):
    for i in range(len(tab)) :
        try :
            if(len(tab[i]) == 1) :
                rem = []
                for j in tab[i+1:]:
                    print(j)
                    if (len(j) == 1) :
                        for z in rem:
                            tab.remove(z)
                            break
                    rem.append(j)
                print(rem)
        except :
            break
    return tab
def tab2req(data,tab):
    salles = data["salles"]
    noeuds = data["noeuds"]
    salles.update(noeuds)
    final = ""
    for i in tab :
        final += str(i)+','+salles[i][0]+','+salles[i][1]+'|'
    return final

# Graphe de test
data = Getdata("PLAN.txt")
edges = data["chemins"]

# Conversion du graphe en dictionnaire
graph = {}
for edge in edges:
    node1 = edge[0]
    node2 = edge[1]
    weight = int(float(edge[2]))

    if node1 not in graph:
        graph[node1] = {}
    if node2 not in graph:
        graph[node2] = {}

    graph[node1][node2] = weight
    graph[node2][node1] = weight


print(graph)
# Calcul des distances les plus courtes
"""
distances = dijkstra(graph, s,end)
# Affichage des distances
print(distances)
print(deriv(distances))
"""
import socket
from threading import Thread
from socketserver import ThreadingMixIn


class myThread(Thread):
    def __init__(self, ip, port):
        Thread.__init__(self)
        self.ip = ip
        self.port = port
        print("[+] Nouveau thread démarré pour " + ip + ":" + str(port))

    def run(self):
        while True:

            try :
                d = con.recv(2048)
                d = d.decode("Utf8")
                print("Le serveur a reçu des données:", d)
                if d == "" :
                    return
                datas = d.split(",")
                print("datas",datas)
                distances = dijkstra(graph, datas[1], datas[2])
                #distances = deriv(distances)
                print("distances", distances)
                my_string = tab2req(data,distances)
                con.send(my_string.encode("Utf8"))
            except :
                con.send("Michem404".encode("Utf8"))
                return


# Programme du serveur TCP
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
s.bind(('10.192.27.243', 9998))
mythreads = []


while True:
    s.listen(5)
    print("Serveur: en attente de connexions des clients TCP ...")
    (con, (ip, port)) = s.accept()
    mythread = myThread(ip, port)
    mythread.start()
    mythreads.append(mythread)
for t in mythreads:
    t.join()
# Out:
# {'M.1.35': {'M.1.1': 29, '1': 136}, 'M.1.1': {'M.1.35': 29, 'M.1.34': 17}, 'M.1.34': {'M.1.1': 17, 'M.1.2': 22}, 'M.1.2': {'M.1.34': 22, 'M.1.33': 23}, 'M.1.33': {'M.1.2': 23, '1': 45}, '1': {'M.1.33': 45, 'M.1.3': 47, 'esc 1': 32, 'M.1.32': 40, 'M.1.35': 136, '2': 391}, 'M.1.3': {'1': 47, 'M.1.4': 33, 'esc 1': 15}, 'M.1.4': {'M.1.3': 33, 'U2.1.7': 58}, 'U2.1.7': {'M.1.4': 58, 'U2.1.6': 47}, 'U2.1.6': {'U2.1.7': 47, 'U2.1.8': 77}, 'U2.1.8': {'U2.1.6': 77, 'U2.1.5': 35}, 'U2.1.5': {'U2.1.8': 35, 'U2.1.4': 49}, 'U2.1.4': {'U2.1.5': 49, '2': 45}, '2': {'U2.1.4': 45, 'U2.1.17': 106, 'esc 4': 30, '1': 391, '12': 353}, 'esc 1': {'1': 32, 'M.1.3': 15}, 'M.1.32': {'1': 40, 'M.1.31': 67}, 'M.1.31': {'M.1.32': 67, 'M.1.5': 30}, 'M.1.5': {'M.1.31': 30, 'M.1.30': 18}, 'M.1.30': {'M.1.5': 18, 'M.1.6': 28}, 'M.1.6': {'M.1.30': 28, 'M.1.29': 17}, 'M.1.29': {'M.1.6': 17, 'M.1.7': 20}, 'M.1.7': {'M.1.29': 20, 'M.1.28': 13}, 'M.1.28': {'M.1.7': 13, 'M.1.27': 65}, 'M.1.27': {'M.1.28': 65, '11': 56}, '11': {'M.1.27': 56, 'esc 2': 43, 'M.1.26': 36, 'W.C.F 1': 42, '12': 398, '10': 389}, 'esc 2': {'11': 43}, 'M.1.26': {'11': 36, 'M.1.25': 33}, 'M.1.25': {'M.1.26': 33, 'M.1.8': 33}, 'M.1.8': {'M.1.25': 33, 'M.1.24': 21}, 'M.1.24': {'M.1.8': 21, 'M.1.23': 36}, 'M.1.23': {'M.1.24': 36, 'M.1.9': 22}, 'M.1.9': {'M.1.23': 22, 'M.1.22': 15}, 'M.1.22': {'M.1.9': 15, 'M.1.10': 21}, 'M.1.10': {'M.1.22': 21, 'M.1.21': 22}, 'M.1.21': {'M.1.10': 22, 'M.1.11': 24}, 'M.1.11': {'M.1.21': 24, 'M.1.20': 19}, 'M.1.20': {'M.1.11': 19, 'M.1.19': 36}, 'M.1.19': {'M.1.20': 36, 'M.1.18': 45}, 'M.1.18': {'M.1.19': 45, '10': 29}, '10': {'M.1.18': 29, 'esc 3': 46, 'M.1.17': 39, '11': 389, '9': 398}, 'esc 3': {'10': 46, 'M.1.13': 22}, 'M.1.17': {'10': 39, 'M.1.16': 32}, 'M.1.16': {'M.1.17': 32}, 'M.1.13': {'esc 3': 22, 'M.1.12': 16, 'M.1.13': 0}, 'M.1.12': {'M.1.13': 16, 'U2.1.51': 56}, 'W.C.F 1': {'11': 42, 'W.C.H 1': 33}, 'W.C.H 1': {'W.C.F 1': 33, 'U2.1.21': 66}, 'U2.1.21': {'W.C.H 1': 66, 'U2.1.20': 44}, 'U2.1.20': {'U2.1.21': 44, 'U2.1.22': 101}, 'U2.1.22': {'U2.1.20': 101, 'U2.1.19': 35}, 'U2.1.19': {'U2.1.22': 35, 'W.C.H 2': 12}, 'W.C.H 2': {'U2.1.19': 12, 'W.C.F 2': 39}, 'W.C.F 2': {'W.C.H 2': 39, '12': 26}, '12': {'W.C.F 2': 26, 'U2.1.23': 75, 'U2.1.15': 43, 'U2.1.25': 58, '2': 353, '9': 385, '11': 398, '6': 413}, 'U2.1.23': {'12': 75, 'U2.1.42': 60}, 'U2.1.42': {'U2.1.23': 60, 'U2.1.41': 17}, 'U2.1.41': {'U2.1.42': 17, 'U2.1.43': 38}, 'U2.1.43': {'U2.1.41': 38, 'U2.1.40': 10}, 'U2.1.40': {'U2.1.43': 10, 'U2.1.44': 38}, 'U2.1.44': {'U2.1.40': 38, 'U2.1.39': 10}, 'U2.1.39': {'U2.1.44': 10, 'U2.1.38': 16}, 'U2.1.38': {'U2.1.39': 16, 'U2.1.45': 11}, 'U2.1.45': {'U2.1.38': 11, 'U2.1.46': 63}, 'U2.1.46': {'U2.1.45': 63, '9': 47}, '9': {'U2.1.46': 47, 'U2.1.47': 47, 'esc 5': 31, '8': 421, '12': 385, '10': 398}, 'U2.1.47': {'9': 47, 'U2.1.54': 65}, 'U2.1.54': {'U2.1.47': 65, 'U2.1.48': 15}, 'U2.1.48': {'U2.1.54': 15, 'U2.1.53': 23}, 'U2.1.53': {'U2.1.48': 23, 'U2.1.49': 14}, 'U2.1.49': {'U2.1.53': 14, 'U2.1.50': 61}, 'U2.1.50': {'U2.1.49': 61, 'U2.1.51': 33, 'U2.1.52': 19}, 'U2.1.51': {'U2.1.50': 33, 'U2.1.52': 14, 'M.1.12': 56}, 'U2.1.52': {'U2.1.50': 19, 'U2.1.51': 14}, 'U2.1.17': {'2': 106, 'U2.1.16': 49}, 'U2.1.16': {'U2.1.17': 49, 'U2.1.18': 83}, 'U2.1.18': {'U2.1.16': 83, 'U2.1.15': 72}, 'U2.1.15': {'U2.1.18': 72, '12': 43}, 'esc 4': {'2': 30, 'W.C 2': 31}, 'esc 5': {'9': 31, 'W.C 1': 31}, 'W.C 1': {'esc 5': 31, 'U2.1.55': 45}, 'U2.1.55': {'W.C 1': 45, 'U2.1.37': 51}, 'U2.1.37': {'U2.1.55': 51, 'U2.1.56': 23}, 'U2.1.56': {'U2.1.37': 23, 'U2.1.36': 17, 'U2.1.57': 33, '8': 25}, 'U2.1.36': {'U2.1.56': 17, 'U2.1.35': 58}, 'U2.1.35': {'U2.1.36': 58, 'U2.1.34': 49}, 'U2.1.34': {'U2.1.35': 49, 'U2.1.57': 58}, 'U2.1.57': {'U2.1.34': 58, 'U2.1.56': 33}, '8': {'U2.1.56': 25, 'U2.1.59': 11, '6': 380, '9': 421}, 'U2.1.59': {'8': 11, 'W.C.F 3': 15}, 'W.C.F 3': {'U2.1.59': 15, 'W.C.H 3': 34}, 'W.C.H 3': {'W.C.F 3': 34, 'U2.1.61': 38}, 'U2.1.61': {'W.C.H 3': 38, 'U2.1.33': 20}, 'U2.1 ...
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:44604
# Le serveur a reçu des données: ,U2.1.6,M.1.35
# datas ['\x00\x0e', 'U2.1.6', 'M.1.35']
# start,end U2.1.6 M.1.35
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.35']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44610
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,U2.1.5,M.1.35
# datas ['\x00\x0e', 'U2.1.5', 'M.1.35']
# start,end U2.1.5 M.1.35
# distances
# ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44622
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.5,M.1.35
# datas ['\x00\x0e', 'U2.1.5', 'M.1.35']
# start,end U2.1.5 M.1.35
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44624
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.5,M.1.35
# datas ['\x00\x0e', 'U2.1.5', 'M.1.35']
# start,end U2.1.5 M.1.35
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44636
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44638
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:44640
# Le serveur a reçu des données: ,M.1.33,U2.1.6
# datasServeur: en attente de connexions des clients TCP ... ['\x00\x0e', 'M.1.33', 'U2.1.6']
# start,end M.1.33 U2.1.6
# distances ['M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
#
# [+] Nouveau thread démarré pour 10.192.27.152:44642
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.33,U2.1.6
# datas ['\x00\x0e', 'M.1.33', 'U2.1.6']
# start,end M.1.33 U2.1.6
# distances ['M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# [+] Nouveau thread démarré pour 10.192.27.152:44644
# Le serveur a reçu des données:Serveur: en attente de connexions des clients TCP ...
#  ,M.1.33,U2.1.6
# datas ['\x00\x0e', 'M.1.33', 'U2.1.6']
# start,end M.1.33 U2.1.6
# distances ['M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# [+] Nouveau thread démarré pour 10.192.27.152:44646
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.33,U2.1.6
# datas ['\x00\x0e', 'M.1.33', 'U2.1.6']
# start,end M.1.33 U2.1.6
# distances ['M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# Le serveur a reçu des données:Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44648
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.33,U2.1.6
# datas ['\x00\x0e', 'M.1.33', 'U2.1.6']
# start,end M.1.33 U2.1.6
# distances ['M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# [+] Nouveau thread démarré pour 10.192.27.152:44650
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.33,U2.1.6
# datas ['\x00\x0e', 'M.1.33', 'U2.1.6']
# start,end M.1.33 U2.1.6
# distances ['M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# Le serveur a reçu des données:Le serveur a reçu des données:
#
# [+] Nouveau thread démarré pour 10.192.27.152:44680
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# [+] Nouveau thread démarré pour 10.192.27.152:44682
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# [+] Nouveau thread démarré pour 10.192.27.152:44684
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44702
# Le serveur a reçu des données: ,U2.1.5,M.1.35
# datas ['\x00\x0e', 'U2.1.5', 'M.1.35']
# start,end U2.1.5 M.1.35
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.35']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44744
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.6,M.1.34
# datas ['\x00\x0e', 'U2.1.6', 'M.1.34']
# start,end U2.1.6 M.1.34
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# [+] Nouveau thread démarré pour 10.192.27.152:44746
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.6,M.1.34
# datas ['\x00\x0e', 'U2.1.6', 'M.1.34']
# start,end U2.1.6 M.1.34
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44748
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.5,M.1.34
# datas ['\x00\x0e', 'U2.1.5', 'M.1.34']
# start,end U2.1.5 M.1.34
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# [+] Nouveau thread démarré pour 10.192.27.152:44750
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,U2.1.5,M.1.34
# datas ['\x00\x0e', 'U2.1.5', 'M.1.34']
# start,end U2.1.5 M.1.34
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
#
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44806
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.5,M.1.34
# datas ['\x00\x0e', 'U2.1.5', 'M.1.34']
# start,end U2.1.5 M.1.34
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44816
# Le serveur a reçu des données: ,U2.1.6,M.1.34
# datas ['\x00\x0e', 'U2.1.6', 'M.1.34']
# start,end U2.1.6 Serveur: en attente de connexions des clients TCP ...M.1.34
#
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44820
# Le serveur a reçu des données: ,U2.1.5,M.1.34
# datas ['\x00\x0e', 'U2.1.5', 'M.1.34']
# start,end U2.1.5 M.1.34
# distances ['U2.1.5', 'U2.1.8', 'U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44824
# Le serveur a reçu des données: ,U2.1.6,M.1.34
# datas ['\x00\x0e', 'U2.1.6', 'M.1.34']
# start,end U2.1.6 M.1.34
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:44826
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.6,M.1.34
# datas ['\x00\x0e', 'U2.1.6', 'M.1.34']
# start,end U2.1.6 M.1.34
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44834
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.6,M.1.34
# datas ['\x00\x0e', 'U2.1.6', 'M.1.34']
# start,end U2.1.6 M.1.34
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.33', 'M.1.2', 'M.1.34']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44838
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44844
# Le serveur a reçu des données: ,U2.1.18,U2.1.5
# datas ['\x00\x0f', 'U2.1.18', 'U2.1.5']
# start,end U2.1.18 U2.1.5
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', 'U2.1.4', 'U2.1.5']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44846
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44850
# Le serveur a reçu des données: Serveur: en attente de connexions des clients TCP ...
# ,M.1.34,U2.1.6
# datas ['\x00\x0e', 'M.1.34', 'U2.1.6']
# start,end M.1.34 U2.1.6
# distances ['M.1.34', 'M.1.2', 'M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44856
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44866
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.5
# datas ['\x00\x0e', 'M.1.35', 'U2.1.5']
# start,end M.1.35 U2.1.5
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44868
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44890
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données:
# ,M.1.35,U2.1.7
# datas ['\x00\x0e', 'M.1.35', 'U2.1.7']
# start,end M.1.35 U2.1.7
# distances ['M.1.35', '1', 'M.1.3', 'M.1.4', 'U2.1.7']
# [+] Nouveau thread démarré pour 10.192.27.152:44894
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44896
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44898
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données:
# ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44918
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44922
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44928
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44930
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44934
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44936
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44950
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
#
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44952
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.34,U2.1.6
# datas ['\x00\x0e', 'M.1.34', 'U2.1.6']
# start,end M.1.34 U2.1.6
# distances ['M.1.34', 'M.1.2', 'M.1.33', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44954
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.34,U2.1.18
# datas ['\x00\x0f', 'M.1.34', 'U2.1.18']
# start,end M.1.34 U2.1.18
# distances ['M.1.34', 'M.1.2', 'M.1.33', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44958
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end Serveur: en attente de connexions des clients TCP ...M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44962
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44970
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']Serveur: en attente de connexions des clients TCP ...
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44984
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44986
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44988
# Le serveur a reçu des données: Serveur: en attente de connexions des clients TCP ...
# ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44992
# Serveur: en attente de connexions des clients TCP ...
# ,M.1.6,U2.1.5reçu des données:
# datas ['\x00\r', 'M.1.6', 'U2.1.5']
# start,end M.1.6 U2.1.5
# distances ['M.1.6', 'M.1.30', 'M.1.5', 'M.1.31', 'M.1.32', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:44996
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45004
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45006
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45054
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45080
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45082
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45084
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.4,U2.1.18
# datas ['\x00\x0e', 'M.1.4', 'U2.1.18']
# start,end M.1.4 U2.1.18
# distances ['M.1.4', 'U2.1.7', 'U2.1.6', 'U2.1.8', 'U2.1.5', 'U2.1.4', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45086
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45088
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données:
# ,M.1.30,U2.1.18
# datas ['\x00\x0f', 'M.1.30', 'U2.1.18']
# start,end M.1.30 U2.1.18
# distances ['M.1.30', 'M.1.6', 'M.1.29', 'M.1.7', 'M.1.28', 'M.1.27', '11', '12', 'U2.1.15', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45090
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.30,U2.1.6
# datas ['\x00\x0e', 'M.1.30', 'U2.1.6']
# start,end M.1.30 U2.1.6
# distances ['M.1.30', 'M.1.5', 'M.1.31', 'M.1.32', '1', 'M.1.3', 'M.1.4', 'U2.1.7', 'U2.1.6']
# [+] Nouveau thread démarré pour 10.192.27.152:45092
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.30,U2.1.7
# datas ['\x00\x0e', 'M.1.30', 'U2.1.7']
# start,end M.1.30 U2.1.7
# distances ['M.1.30', 'M.1.5', 'M.1.31', 'M.1.32', '1', 'M.1.3', 'M.1.4', 'U2.1.7']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45094
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.30,U2.1.18
# datas ['\x00\x0f', 'M.1.30', 'U2.1.18']
# start,end M.1.30 U2.1.18
# distances ['M.1.30', 'M.1.6', 'M.1.29', 'M.1.7', 'M.1.28', 'M.1.27', '11', '12', 'U2.1.15', 'U2.1.18']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45096
# Le serveur a reçu des données: ,M.1.27,U2.1.18
# datas ['\x00\x0f', 'M.1.27', 'U2.1.18']
# start,end M.1.27 U2.1.18
# distances ['M.1.27', '11', '12', 'U2.1.15', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45098
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.2,U2.1.18
# datas ['\x00\x0e', 'M.1.2', 'U2.1.18']
# start,end M.1.2 U2.1.18
# distances ['M.1.2', 'M.1.33', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45102
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.2,U2.1.18
# datas ['\x00\x0e', 'M.1.2', 'U2.1.18']
# start,end M.1.2 U2.1.18
# distances ['M.1.2', 'M.1.33', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45224
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45238
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45248
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45252
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end
#  M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45254
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45272
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45274
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45282
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,U2.1.18,M.1.35
# datas ['\x00\x0f', 'U2.1.18', 'M.1.35']
# start,end U2.1.18 M.1.35
# distances
# ['U2.1.18', 'U2.1.16', 'U2.1.17', '2', '1', 'M.1.35']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45290
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45294
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45296
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45298
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45300
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45302
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datasServeur: en attente de connexions des clients TCP ... ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45312
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45316
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:45318
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données:
# ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45320
# Le serveur a reçu des données:Serveur: en attente de connexions des clients TCP ...
#  ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45322
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45324
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# [+] Nouveau thread démarré pour 10.192.27.152:45326
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:Le serveur a reçu des données:  Le serveur a reçu des données:
# Le serveur a reçu des données:
#
# Le serveur a reçu des données:
# Le serveur a reçu des données:
#
# [+] Nouveau thread démarré pour 10.192.27.152:45328
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45330
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45332
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:Le serveur a reçu des données:Le serveur a reçu des données:
#
#
# [+] Nouveau thread démarré pour 10.192.27.152:45342
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:45344
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:45346
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45348
# Le serveur a reçu des données: Serveur: en attente de connexions des clients TCP ...
# ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45350
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# [+] Nouveau thread démarré pour 10.192.27.152:45352
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances Serveur: en attente de connexions des clients TCP ...
# ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45354
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# [+] Nouveau thread démarré pour 10.192.27.152:45356
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# [+] Nouveau thread démarré pour 10.192.27.152:45358
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45362
# Le serveur a reçu des données: ,M.1.35,U2.1.18Serveur: en attente de connexions des clients TCP ...
#
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45364
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45366
# Le serveur a reçu des données:Serveur: en attente de connexions des clients TCP ...
#  ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45368
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances Serveur: en attente de connexions des clients TCP ...['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# [+] Nouveau thread démarré pour 10.192.27.152:45370
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
#
# [+] Nouveau thread démarré pour 10.192.27.152:45372
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45374
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45376
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end
#  M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# [+] Nouveau thread démarré pour 10.192.27.152:45378
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données: Le serveur a reçu des données:
#
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45380
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données:
# ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# [+] Nouveau thread démarré pour 10.192.27.152:45406
# Serveur: en attente de connexions des clients TCP ...
# Le serveur a reçu des données: ,U2.1.6,M.1.35
# datas ['\x00\x0e', 'U2.1.6', 'M.1.35']
# start,end U2.1.6 M.1.35
# distances ['U2.1.6', 'U2.1.7', 'M.1.4', 'M.1.3', '1', 'M.1.35']
# [+] Nouveau thread démarré pour 10.192.27.152:45408
# Serveur: en attente de connexions des clients TCP ...Le serveur a reçu des données: ,M.1.35,U2.1.18
# datas ['\x00\x0f', 'M.1.35', 'U2.1.18']
# start,end M.1.35 U2.1.18
# distances ['M.1.35', '1', '2', 'U2.1.17', 'U2.1.16', 'U2.1.18']
# Le serveur a reçu des données:
# Le serveur a reçu des données:
